# %%
# !git clone https://github.com/Legal-NLP-EkStep/legal_NER.git
# Out:
# Cloning into 'legal_NER'...
# remote: Enumerating objects: 329, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 329 (delta 17), reused 13 (delta 13), pack-reused 309
# Receiving objects: 100% (329/329), 6.23 MiB | 20.13 MiB/s, done.
# Resolving deltas: 100% (184/184), done.

# %%
# !pip install spacy-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 53 kB 1.2 MB/s
# ...
#      |████████████████████████████████| 4.7 MB 14.4 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 56.8 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 47.2 MB/s
# ...
#      |████████████████████████████████| 182 kB 72.2 MB/s
# ...

# %%
# !python -m spacy train ./legal_NER/training/config.cfg --output ./output --gpu-id 0 --paths.train legal_NER/training/Combined_Data_Judgement_Preamble_spacy_format/train.spacy --paths.dev ./legal_NER/training/Combined_Data_Judgement_Preamble_spacy_format/dev.spacy
# Out:
# ✔ Created output directory: output
# ℹ Saving to output directory: output
# ℹ Using GPU: 0
#
# =========================== Initializing pipeline ===========================
# [2022-12-06 21:19:45,494] [INFO] Set up nlp object from config
# INFO:spacy:Set up nlp object from config
# [2022-12-06 21:19:45,504] [INFO] Pipeline: ['transformer', 'ner']
# INFO:spacy:Pipeline: ['transformer', 'ner']
# [2022-12-06 21:19:45,508] [INFO] Created vocabulary
# INFO:spacy:Created vocabulary
# [2022-12-06 21:19:45,509] [INFO] Finished initializing nlp object
# INFO:spacy:Finished initializing nlp object
# ...
# Some weights of the model checkpoint at roberta-base were not used when initializing RobertaModel: ['lm_head.dense.bias', 'lm_head.layer_norm.weight', 'lm_head.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight']
# ...

# %%
pip install https://huggingface.co/opennyaiorg/en_legal_ner_trf/resolve/main/en_legal_ner_trf-any-py3-none-any.whl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 446.7 MB 24 kB/s
# ...
#      |████████████████████████████████| 6.2 MB 8.3 MB/s
# ...
#      |████████████████████████████████| 13.7 MB 15.9 MB/s
# ...
#      |████████████████████████████████| 671 kB 22.5 MB/s
# ...
#      |████████████████████████████████| 53 kB 2.0 MB/s
# ...
#      |████████████████████████████████| 4.4 MB 24.4 MB/s
# ...
#   Attempting uninstall: typer
#     Found existing installation: typer 0.7.0
#     Uninstalling typer-0.7.0:
#       Successfully uninstalled typer-0.7.0
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 1.10.2
#     Uninstalling pydantic-1.10.2:
#       Successfully uninstalled pydantic-1.10.2
#   Attempting uninstall: thinc
#     Found existing installation: thinc 8.1.5
#     Uninstalling thinc-8.1.5:
#       Successfully uninstalled thinc-8.1.5
#   Attempting uninstall: transformers
# ...

# %%
pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.2.0/en_core_web_sm-3.2.0-py3-none-any.whl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 13.9 MB 3.5 MB/s
# ...
#   Attempting uninstall: en-core-web-sm
#     Found existing installation: en-core-web-sm 3.4.1
#     Uninstalling en-core-web-sm-3.4.1:
#       Successfully uninstalled en-core-web-sm-3.4.1
# ...

# %%
# !python /content/legal_NER/data_preparation.py

# %%
# !python /content/legal_NER/legal_ner.py
# Out:
# Seperating Preamble took 0.0011315345764160156
# Creating doc for jdgement  took 0.00045490264892578125
# Traceback (most recent call last):
#   File "/content/legal_NER/legal_ner.py", line 60, in <module>
#     combined_doc = extract_entities_from_judgment_text(txt,legal_nlp,preamble_spiltting_nlp,text_type='sent',do_postprocess=True)
#   File "/content/legal_NER/legal_ner.py", line 30, in extract_entities_from_judgment_text
#     print(len(doc_judgment.ents))
# AttributeError: 'NoneType' object has no attribute 'ents'

# %%
import spacy
from data_preparation import get_text_from_indiankanoon_url
from spacy import displacy
from legal_ner import extract_entities_from_judgment_text
import urllib

legal_nlp=spacy.load('en_legal_ner_trf')
judgment_text = urllib.request.urlopen('https://raw.githubusercontent.com/OpenNyAI/Opennyai/master/samples/sample_judgment1.txt').read().decode()

preamble_spiltting_nlp = spacy.load('en_core_web_sm')
run_type='sent' ###  trade off between accuracy and runtime
do_postprocess=True 
combined_doc = extract_entities_from_judgment_text(judgment_text,legal_nlp,preamble_spiltting_nlp,run_type,do_postprocess)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-14-d28249707d4b> in <module>
#       1 import spacy
# ----> 2 from data_preparation import get_text_from_indiankanoon_url
#       3 from spacy import displacy
#       4 from legal_ner import extract_entities_from_judgment_text
#       5 import urllib
#
# ModuleNotFoundError: No module named 'data_preparation'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
extracted_ent_labels = list(set([i.label_ for i in combined_doc.ents]))
colors = {'COURT': "#bbabf2", 'PETITIONER': "#f570ea", "RESPONDENT": "#cdee81", 'JUDGE': "#fdd8a5",
          "LAWYER": "#f9d380", 'WITNESS': "violet", "STATUTE": "#faea99", "PROVISION": "yellow",
          'CASE_NUMBER': "#fbb1cf", "PRECEDENT": "#fad6d6", 'DATE': "#b1ecf7", 'OTHER_PERSON': "#b0f6a2",
          'ORG':'#a57db5','GPE':'#7fdbd4'}
options = {"ents": extracted_ent_labels, "colors": colors}
displacy.serve(combined_doc, style='ent',port=8080,options=options)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-a946f4876b9e> in <module>
# ----> 1 extracted_ent_labels = list(set([i.label_ for i in combined_doc.ents]))
#       2 colors = {'COURT': "#bbabf2", 'PETITIONER': "#f570ea", "RESPONDENT": "#cdee81", 'JUDGE': "#fdd8a5",
#       3           "LAWYER": "#f9d380", 'WITNESS': "violet", "STATUTE": "#faea99", "PROVISION": "yellow",
#       4           'CASE_NUMBER': "#fbb1cf", "PRECEDENT": "#fad6d6", 'DATE': "#b1ecf7", 'OTHER_PERSON': "#b0f6a2",
#       5           'ORG':'#a57db5','GPE':'#7fdbd4'}
#
# NameError: name 'combined_doc' is not defined
